# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Book1.csv")
df
# Out:
#                                               user_name  \
# 0                                    The Cricket Digest
# 1                                             Sportstar
# 2                                CRICKETEER UPDATES 🎉🎊🏏
# 3                                       The Niche Cache
# 4                                         The Cricketer
# ...                                                 ...
# 4115                     Nekraj Bhartiya ExpertFreeTips
# 4116                                        SportsTiger
# 4117                                        SportsTiger
# 4118  And the countdown for most awaited cricket fes...
# 4119  Stay connected with #SportsTiger for all the l...
#
#                     user_location  \
# 0                       Australia
# 1                             NaN
# 2                  Cardiff, Wales
# 3     South Auckland, New Zealand
# 4                 London, England
# ...                           ...
# 4115                        India
# 4116            Jaipur, Rajasthan
# 4117            Jaipur, Rajasthan
# 4118                          NaN
# 4119                          NaN
#
#                                        user_description      user_created  \
# 0                                    The Cricket Digest  09-08-2021 04:31
# 1     India's No. 1 sports magazine\n\nFacebook: htt...  28-08-2015 06:22
# 2     Researcher, Welsh, Cricket Analyst , Sports Pr...  27-10-2020 18:04
# 3     We love sports and music and other shit. https...  03-06-2013 02:07
# 4     The world’s No.1 cricket magazine and organise...  02-04-2009 15:34
# ...                                                 ...               ...
# 4115  Daily Cricket Betting Tips, Dream11 Team, Spec...  27-07-2016 11:01
# 4116  Follow SportsTiger for latest sports news arou...  12-02-2020 09:11
# 4117  Follow SportsTiger for latest sports news arou...  12-02-2020 09:11
# 4118                                                NaN               NaN
# 4119                                                NaN               NaN
#
#       user_followers  user_friends  user_favourites user_verified  \
# 0                3.0          77.0              0.0         False
# 1            29653.0         410.0            846.0          True
# 2              403.0         323.0           3072.0         False
# 3             2047.0        1547.0           3488.0         False
# 4           149893.0        2198.0           6564.0          True
# ...              ...           ...              ...           ...
# 4115          7151.0          83.0           6432.0         False
# 4116          1866.0          70.0            122.0         False
# 4117          1866.0          70.0            122.0         False
# 4118             NaN           NaN              NaN           NaN
# 4119             NaN           NaN              NaN           NaN
#
#                   date                                               text  \
# 0     26-08-2021 23:58  There have been notable exclusions from IPL pr...
# 1     26-08-2021 22:30  #CSK batsman Faf du Plessis, who had a terrifi...
# 2     26-08-2021 22:25  England 1st innings lead is already 345 Stumps...
# 3     26-08-2021 22:18  Kiwi #IPL2021 crew for the re-jigged comp...\n...
# 4     26-08-2021 22:00  Adil Rashid will play in the IPL after signing...
# ...                ...                                                ...
# 4115  21-08-2021 05:19  BPH vs SOB The Hundred Men Competition Match P...
# 4116  21-08-2021 05:11  AMAZING FACTS OF IPL | 29 DAYS TO GO!!\n\nKier...
# 4117  21-08-2021 05:08                                      #29DaysToGo 🗓
# 4118               NaN                                                NaN
# 4119               NaN                                                NaN
#
#                                                hashtags              source  \
# 0                                    ['IPL2021', 'IPL']  Twitter for iPhone
# 1                                    ['CSK', 'IPL2021']           TweetDeck
# 2     ['jamesanderson', 'jimmyanderson', 'joeroot', ...  Twitter for iPhone
# 3                              ['IPL2021', 'Blackcaps']     Twitter Web App
# 4                                           ['IPL2021']     Twitter Web App
# ...                                                 ...                 ...
# 4115                                        ['ipl2021']               IFTTT
# 4116  ['Kieronpollard', 'ipl', 'ipl2021', 'iplUAE', ...           TweetDeck
# 4117                                                NaN                 NaN
# 4118                                                NaN                 NaN
# 4119                                                NaN                 NaN
#
#      is_retweet
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 4115      False
# 4116      False
# 4117        NaN
# 4118        NaN
# 4119        NaN
#
# [4120 rows x 13 columns]

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df = df.dropna(subset=['date'])
df
# Out:
# C:\Users\megha\AppData\Local\Temp\ipykernel_17888\345419871.py:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 4113      False
# 4114      False
# 4115      False
# 4116      False
# 4117        NaN
#
# [4118 rows x 13 columns]

# %%
print(df.isnull())
# Out:
#       user_name  user_location  user_description  user_created  \
# 0         False          False             False         False
# 1         False           True             False         False
# 2         False          False             False         False
# 3         False          False             False         False
# 4         False          False             False         False
# ...         ...            ...               ...           ...
# 4113      False          False             False         False
# 4114      False          False             False         False
# 4115      False          False             False         False
# 4116      False          False             False         False
# 4117      False          False             False         False
#
#       user_followers  user_friends  user_favourites  user_verified   date  \
# 0              False         False            False          False  False
# 1              False         False            False          False  False
# 2              False         False            False          False  False
# 3              False         False            False          False  False
# 4              False         False            False          False  False
# ...              ...           ...              ...            ...    ...
# 4113           False         False            False          False  False
# 4114           False         False            False          False  False
# 4115           False         False            False          False  False
# 4116           False         False            False          False  False
# 4117           False         False            False          False  False
#
#        text  hashtags  source  is_retweet
# 0     False     False   False       False
# 1     False     False   False       False
# 2     False     False   False       False
# 3     False     False   False       False
# 4     False     False   False       False
# ...     ...       ...     ...         ...
# 4113  False     False   False       False
# 4114  False     False   False       False
# 4115  False     False   False       False
# 4116  False     False   False       False
# 4117  False      True    True        True
#
# [4118 rows x 13 columns]

# %%
tweets_per_day = df.groupby(df['date'].dt.date).size()
plt.figure(figsize=(10, 6))
tweets_per_day.plot(marker='o')
plt.title('Number of Tweets per Day')
plt.xlabel('Date')
plt.ylabel('Number of Tweets')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from wordcloud import WordCloud

# %%
df['hashtags'] = df['hashtags'].astype(str)
# Out:
# C:\Users\megha\AppData\Local\Temp\ipykernel_17888\474066610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hashtags'] = df['hashtags'].astype(str)

# %%
import re
# Preprocess hashtags: remove punctuation and split by whitespace
all_hashtags = ' '.join(df['hashtags'])
all_hashtags = re.sub(r'[^\w\s]', '', all_hashtags)  # Remove punctuation
all_hashtags = all_hashtags.split()  # Split by whitespace

# Count the frequency of each hashtag
word_counts = {}
for hashtag in all_hashtags:
    word_counts[hashtag] = word_counts.get(hashtag, 0) + 1

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counts)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import re
df['text'] = df['text'].astype(str)
df['hashtags'] = df['hashtags'].astype(str)

stop_words = ['a', 'as','be','an', 'the', 'of', 'on', 'in', 'and', 'is', 'are', 'to', 'for', 'with', 'you', 'your', 'this', 'that', 'it', 'at', 'by', 'from', 'or','will']

combined_text = ' '.join(df['text']) + ' ' + ' '.join(df['hashtags'])

# Preprocess combined text: remove punctuation and convert to lowercase
combined_text = re.sub(r'[^\w\s]', '', combined_text)  # Remove punctuation
combined_text = combined_text.lower()  # Convert to lowercase

# Split the combined text into words
words = combined_text.split()

filtered_words = [word for word in words if word not in stop_words]

# Count the frequency of each word
word_counts = {}
for word in filtered_words:
    word_counts[word] = word_counts.get(word, 0) + 1

# Convert word counts dictionary to DataFrame
word_counts_df = pd.DataFrame(word_counts.items(), columns=['Word', 'Frequency'])
word_counts_df = word_counts_df.sort_values(by='Frequency', ascending=False)
# Print the DataFrame
print(word_counts_df)
# Out:
#                     Word  Frequency
# 14               ipl2021       8329
# 5                    ipl       2795
# 315                  rcb       2349
# 208              cricket       1277
# 334                 2021        808
# ...                  ...        ...
# 5400  httpstcoipw0ukprmi          1
# 5399              yooooo          1
# 5398  httpstcoc8ntnwwmtj          1
# 5397  httpstcoklppml6lxx          1
# 9880                 nan          1
#
# [9881 rows x 2 columns]
# C:\Users\megha\AppData\Local\Temp\ipykernel_17888\3361055678.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].astype(str)
# C:\Users\megha\AppData\Local\Temp\ipykernel_17888\3361055678.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hashtags'] = df['hashtags'].astype(str)

# %%
top_20_words = word_counts_df.head(20)

plt.figure(figsize=(10, 6))
plt.bar(top_20_words['Word'], top_20_words['Frequency'])
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title('Top 20 Most Used Words')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
