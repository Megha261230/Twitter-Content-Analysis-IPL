# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("IPL2020_Tweets.csv")
df
# Out:
# C:\Users\megha\AppData\Local\Temp\ipykernel_39092\3586698690.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("IPL2020_Tweets.csv")
#                    user_name                   user_location  \
# 0         GAURAV DHANAWAT 🇮🇳                     Delhi,India
# 1       🇮🇳🇮🇳 शुभम दोहरे 🇮🇳🇮🇳                   Bhopal, India
# 2              Steven Gordon  Carrickfergus, Northern Irelan
# 3              Bhumish Patel                 Montreal Canada
# 4             cricket22yards                             NaN
# ...                      ...                             ...
# 572958        Kuldeep Pandey                             NaN
# 572959           iknowfactso                  Chennai, India
# 572960         VIVO IPL 2020                        India 🇮🇳
# 572961         Cricket Facts                             NaN
# 572962          K.Ponaravind                 Karaikal, India
#
#                                          user_description    user_created  \
# 0       Live EVS Operator/Coordinator | EX Ten Sports ...  02/04/09 17:06
# 1       👉💯%Bhopali😎\n👉B+🔥\n👉Proud to be an #indian🇮🇳\n...   10/11/16 5:09
# 2       Buns are good but puns are better, best served...  03/04/13 15:03
# 3       Student at Concordia University, Montreal, CA\...  04/07/13 16:24
# 4       We are a cricketing blog highly focusing on th...  02/09/16 19:14
# ...                                                   ...             ...
# 572958      New id\n#memes\n#trolls\n#sarcasam\n#trending  11/06/20 11:06
# 572959  daily interesting facts 🤓\ncrazy factsoftheday...   30/04/19 4:35
# 572960  #IPL2020 #IPL2020 #IPL2020 #IPL2020 #VIVOIPL #...  06/03/16 20:59
# 572961  Follow CricketFacts for the latest news | Prev...   29/12/19 8:42
# 572962                                                NaN  08/07/20 22:07
#
#         user_followers  user_friends  user_favourites  user_verified  \
# 0                147.0         127.0            205.0          False
# 1                113.0         699.0           1412.0          False
# 2                 27.0          57.0             41.0          False
# 3                131.0        1525.0          10343.0          False
# 4                551.0         189.0            160.0          False
# ...                ...           ...              ...            ...
# 572958             4.0          14.0             23.0          False
# 572959            12.0          49.0             13.0          False
# 572960          5644.0          20.0            647.0          False
# 572961           117.0         329.0            808.0          False
# 572962            20.0         485.0             86.0          False
#
#               date                                               text  \
# 0       2020-11-11  Time to change the Bubble from #IPL2020 to #IS...
# 1       2020-11-11  Why is #2020Fixing trending?? \n\nI think rcb ...
# 2       2020-11-11  @ICC And still #rajasthanroyals  finished last...
# 3       2020-11-11  I still remember the bus parade after @mipalta...
# 4       2020-11-11  #IPL2020 \n\nSTATS: Most runs, fastest fifties...
# ...            ...                                                ...
# 572958  2020-08-15  #IPL2020: Tata sons emerge as a strong contend...
# 572959  2020-08-15  For more interesting facts 🤓 follow me @iknowf...
# 572960  2020-08-15  💫England confirm series against Australia in S...
# 572961  2020-08-15  MECC vs BCC: Match 5, ECS T10 Belgium: Dream11...
# 572962  2020-08-15  #ThalaDhoni @msdfansofficial @DHONIism @CskIPL...
#
#                                                  hashtags  \
# 0                                  ['IPL2020', 'ISL2020']
# 1                                          ['2020Fixing']
# 2       ['rajasthanroyals', 'JofraArcher', 'RR', 'jofr...
# 3                                                     NaN
# 4                                             ['IPL2020']
# ...                                                   ...
# 572958                                        ['IPL2020']
# 572959  ['Facts', 'FactCheck', 'factchecking', 'FF7R',...
# 572960                                                NaN
# 572961  ['Cricket', 'IPL2020', 'IPL', 'COVID_19', 'Dre...
# 572962                          ['ThalaDhoni', 'ipl2020']
#
#                      source is_retweet  month    year
# 0        Twitter for iPhone      False   11.0  2020.0
# 1       Twitter for Android      False   11.0  2020.0
# 2       Twitter for Android      False   11.0  2020.0
# 3           Twitter Web App      False   11.0  2020.0
# 4           Twitter Web App      False   11.0  2020.0
# ...                     ...        ...    ...     ...
# 572958  Twitter for Android      False    8.0  2020.0
# 572959  Twitter for Android      False    8.0  2020.0
# 572960  Twitter for Android      False    8.0  2020.0
# 572961  Twitter for Android      False    8.0  2020.0
# 572962  Twitter for Android      False    8.0  2020.0
#
# [572963 rows x 15 columns]

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df = df.dropna(subset=['date'])
df
# Out:
#                    user_name                   user_location  \
# 0         GAURAV DHANAWAT 🇮🇳                     Delhi,India
# 1       🇮🇳🇮🇳 शुभम दोहरे 🇮🇳🇮🇳                   Bhopal, India
# 2              Steven Gordon  Carrickfergus, Northern Irelan
# 3              Bhumish Patel                 Montreal Canada
# 4             cricket22yards                             NaN
# ...                      ...                             ...
# 572958        Kuldeep Pandey                             NaN
# 572959           iknowfactso                  Chennai, India
# 572960         VIVO IPL 2020                        India 🇮🇳
# 572961         Cricket Facts                             NaN
# 572962          K.Ponaravind                 Karaikal, India
#
#                                          user_description    user_created  \
# 0       Live EVS Operator/Coordinator | EX Ten Sports ...  02/04/09 17:06
# 1       👉💯%Bhopali😎\n👉B+🔥\n👉Proud to be an #indian🇮🇳\n...   10/11/16 5:09
# 2       Buns are good but puns are better, best served...  03/04/13 15:03
# 3       Student at Concordia University, Montreal, CA\...  04/07/13 16:24
# 4       We are a cricketing blog highly focusing on th...  02/09/16 19:14
# ...                                                   ...             ...
# 572958      New id\n#memes\n#trolls\n#sarcasam\n#trending  11/06/20 11:06
# 572959  daily interesting facts 🤓\ncrazy factsoftheday...   30/04/19 4:35
# 572960  #IPL2020 #IPL2020 #IPL2020 #IPL2020 #VIVOIPL #...  06/03/16 20:59
# 572961  Follow CricketFacts for the latest news | Prev...   29/12/19 8:42
# 572962                                                NaN  08/07/20 22:07
#
#         user_followers  user_friends  user_favourites  user_verified  \
# 0                147.0         127.0            205.0          False
# 1                113.0         699.0           1412.0          False
# 2                 27.0          57.0             41.0          False
# 3                131.0        1525.0          10343.0          False
# 4                551.0         189.0            160.0          False
# ...                ...           ...              ...            ...
# 572958             4.0          14.0             23.0          False
# 572959            12.0          49.0             13.0          False
# 572960          5644.0          20.0            647.0          False
# 572961           117.0         329.0            808.0          False
# 572962            20.0         485.0             86.0          False
#
#              date                                               text  \
# 0      2020-11-11  Time to change the Bubble from #IPL2020 to #IS...
# 1      2020-11-11  Why is #2020Fixing trending?? \n\nI think rcb ...
# 2      2020-11-11  @ICC And still #rajasthanroyals  finished last...
# 3      2020-11-11  I still remember the bus parade after @mipalta...
# 4      2020-11-11  #IPL2020 \n\nSTATS: Most runs, fastest fifties...
# ...           ...                                                ...
# 572958 2020-08-15  #IPL2020: Tata sons emerge as a strong contend...
# 572959 2020-08-15  For more interesting facts 🤓 follow me @iknowf...
# 572960 2020-08-15  💫England confirm series against Australia in S...
# 572961 2020-08-15  MECC vs BCC: Match 5, ECS T10 Belgium: Dream11...
# 572962 2020-08-15  #ThalaDhoni @msdfansofficial @DHONIism @CskIPL...
#
#                                                  hashtags  \
# 0                                  ['IPL2020', 'ISL2020']
# 1                                          ['2020Fixing']
# 2       ['rajasthanroyals', 'JofraArcher', 'RR', 'jofr...
# 3                                                     NaN
# 4                                             ['IPL2020']
# ...                                                   ...
# 572958                                        ['IPL2020']
# 572959  ['Facts', 'FactCheck', 'factchecking', 'FF7R',...
# 572960                                                NaN
# 572961  ['Cricket', 'IPL2020', 'IPL', 'COVID_19', 'Dre...
# 572962                          ['ThalaDhoni', 'ipl2020']
#
#                      source is_retweet  month    year
# 0        Twitter for iPhone      False   11.0  2020.0
# 1       Twitter for Android      False   11.0  2020.0
# 2       Twitter for Android      False   11.0  2020.0
# 3           Twitter Web App      False   11.0  2020.0
# 4           Twitter Web App      False   11.0  2020.0
# ...                     ...        ...    ...     ...
# 572958  Twitter for Android      False    8.0  2020.0
# 572959  Twitter for Android      False    8.0  2020.0
# 572960  Twitter for Android      False    8.0  2020.0
# 572961  Twitter for Android      False    8.0  2020.0
# 572962  Twitter for Android      False    8.0  2020.0
#
# [572963 rows x 15 columns]

# %%
print(df.isnull())
# Out:
#         user_name  user_location  user_description  user_created  \
# 0           False          False             False         False
# 1           False          False             False         False
# 2           False          False             False         False
# 3           False          False             False         False
# 4           False           True             False         False
# ...           ...            ...               ...           ...
# 572958      False           True             False         False
# 572959      False          False             False         False
# 572960      False          False             False         False
# 572961      False           True             False         False
# 572962      False          False              True         False
#
#         user_followers  user_friends  user_favourites  user_verified   date  \
# 0                False         False            False          False  False
# 1                False         False            False          False  False
# 2                False         False            False          False  False
# 3                False         False            False          False  False
# 4                False         False            False          False  False
# ...                ...           ...              ...            ...    ...
# 572958           False         False            False          False  False
# 572959           False         False            False          False  False
# 572960           False         False            False          False  False
# 572961           False         False            False          False  False
# 572962           False         False            False          False  False
#
#          text  hashtags  source  is_retweet  month   year
# 0       False     False   False       False  False  False
# 1       False     False   False       False  False  False
# 2       False     False   False       False  False  False
# 3       False      True   False       False  False  False
# 4       False     False   False       False  False  False
# ...       ...       ...     ...         ...    ...    ...
# 572958  False     False   False       False  False  False
# 572959  False     False   False       False  False  False
# 572960  False      True   False       False  False  False
# 572961  False     False   False       False  False  False
# 572962  False     False   False       False  False  False
#
# [572963 rows x 15 columns]

# %%
tweets_per_day = df.groupby(df['date'].dt.date).size()
plt.figure(figsize=(10, 6))
tweets_per_day.plot(marker='o')
plt.title('Number of Tweets per Day')
plt.xlabel('Date')
plt.ylabel('Number of Tweets')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from wordcloud import WordCloud

# %%
df['hashtags'] = df['hashtags'].astype(str)

# %%
import re
# Preprocess hashtags: remove punctuation and split by whitespace
all_hashtags = ' '.join(df['hashtags'])
all_hashtags = re.sub(r'[^\w\s]', '', all_hashtags)  # Remove punctuation
all_hashtags = all_hashtags.split()  # Split by whitespace

# Count the frequency of each hashtag
word_counts = {}
for hashtag in all_hashtags:
    word_counts[hashtag] = word_counts.get(hashtag, 0) + 1

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counts)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import re
df['text'] = df['text'].astype(str)
df['hashtags'] = df['hashtags'].astype(str)

stop_words = ['a', 'an', 'the', 'of', 'on', 'in', 'and', 'is', 'are', 'i','be','to', 'for', 'with', 'you', 'your', 'this', 'that', 'it', 'at', 'by', 'from', 'or','will']

combined_text = ' '.join(df['text']) + ' ' + ' '.join(df['hashtags'])

# Preprocess combined text: remove punctuation and convert to lowercase
combined_text = re.sub(r'[^\w\s]', '', combined_text)  # Remove punctuation
combined_text = combined_text.lower()  # Convert to lowercase

# Split the combined text into words
words = combined_text.split()

filtered_words = [word for word in words if word not in stop_words]

# Count the frequency of each word
word_counts = {}
for word in filtered_words:
    word_counts[word] = word_counts.get(word, 0) + 1

# Convert word counts dictionary to DataFrame
word_counts_df = pd.DataFrame(word_counts.items(), columns=['Word', 'Frequency'])
word_counts_df = word_counts_df.sort_values(by='Frequency', ascending=False)
# Print the DataFrame
print(word_counts_df)
# Out:
#                       Word  Frequency
# 3                  ipl2020     794071
# 17                     ipl     143383
# 59273                  nan     110095
# 562                    csk      99183
# 14                     rcb      71369
# ...                    ...        ...
# 197581        makhayantini          1
# 197580        steynmakhaya          1
# 197579  httpstcoxpyoua1ftn          1
# 197578  httpstcofwfbbmig6r          1
# 509900           mahistyle          1
#
# [509901 rows x 2 columns]

# %%
top_20_words = word_counts_df.head(20)

plt.figure(figsize=(10, 6))
plt.bar(top_20_words['Word'], top_20_words['Frequency'])
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title('Top 20 Most Used Words')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
